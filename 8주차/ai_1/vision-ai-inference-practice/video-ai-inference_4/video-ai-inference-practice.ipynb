# %%
import os
import yt_dlp
import cv2
from ultralytics import YOLO
#from moviepy.editor import ImageSequenceClip

# %% [markdown]
# ### 1. Yutube 영상 다운로드

# %%
# 다운로드할 YouTube URL
url = "https://www.youtube.com/shorts/vwETAy4mIt8"

# yt-dlp 설정
ydl_opts = {
    "format": "best",
    "outtmpl": "downloaded_video.%(ext)s",
}

# 다운로드
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/vwETAy4mIt8
# [youtube] vwETAy4mIt8: Downloading webpage
# [youtube] vwETAy4mIt8: Downloading ios player API JSON
# [youtube] vwETAy4mIt8: Downloading mweb player API JSON
# [youtube] vwETAy4mIt8: Downloading m3u8 information
# [info] vwETAy4mIt8: Downloading 1 format(s): 18
# [download] Destination: downloaded_video.mp4
# [download] 100% of    2.91MiB in 00:00:01 at 1.60MiB/s

# %% [markdown]
# ### 2. 동영상의 fps 정보

# %%
# 동영상 파일 경로
video_path = "downloaded_video.mp4"

# 동영상 파일 열기
cap = cv2.VideoCapture(video_path)

# FPS 가져오기
fps = cap.get(cv2.CAP_PROP_FPS)
print("FPS:", fps)

# 동영상 파일 닫기
cap.release()
# Out:
# FPS: 30.0

# %% [markdown]
# ### 3. 동영상을 프레임 단위로 분할

# %%
video_path = "downloaded_video.mp4"

# cv2를 이용해 동영상 파일 열기
cap = cv2.VideoCapture(video_path)

# 프레임을 저장할 디렉토리 생성
output_dir = "frames2"
os.makedirs(output_dir, exist_ok=True)

# 프레임 단위로 이미지로 저장
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    # 이미지 파일로 프레임 저장
    frame_path = os.path.join(output_dir, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_path, frame)
    frame_count += 1

# 동영상 파일 닫기
cap.release()
print(f"총 {frame_count}개의 프레임이 저장되었습니다.")
# Out:
# 총 1305개의 프레임이 저장되었습니다.

# %% [markdown]
# ### 4. YOLOv8 추론

# %%
# Load a model
model = YOLO("yolov8n.pt")  # pretrained YOLO8n model

# "frames" 디렉토리 안에 있는 파일과 폴더 목록을 가져옴
frames = os.listdir("frames2/")

# 원하는 디렉토리 경로 설정
directory_path = "results2"

# 디렉토리가 없으면 생성
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"디렉토리 '{directory_path}'가 생성되었어.")
else:
    print(f"디렉토리 '{directory_path}'가 이미 존재해.")

for frame in frames:
    # YOLOv8 모델을 사용하여 객체 감지 수행
    results = model("frames2/" + frame)  # , device="mps" (맥북)

    # Process results list
    for result in results:
        result.save(filename="results2/" + frame)  # save to disk
# Out:
# 디렉토리 'results2'가 생성되었어.
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0320.jpg: 640x384 1 person, 226.5ms
# Speed: 1.6ms preprocess, 226.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0763.jpg: 640x384 (no detections), 97.3ms
# Speed: 2.1ms preprocess, 97.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0148.jpg: 640x384 1 person, 111.6ms
# Speed: 1.2ms preprocess, 111.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1032.jpg: 640x384 1 person, 1 cell phone, 104.5ms
# Speed: 2.4ms preprocess, 104.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0840.jpg: 640x384 3 persons, 1 umbrella, 109.3ms
# Speed: 2.4ms preprocess, 109.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0307.jpg: 640x384 1 person, 100.9ms
# Speed: 2.5ms preprocess, 100.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0975.jpg: 640x384 4 persons, 128.4ms
# Speed: 1.4ms preprocess, 128.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1149.jpg: 640x384 1 person, 105.2ms
# Speed: 3.1ms preprocess, 105.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0883.jpg: 640x384 3 persons, 118.0ms
# Speed: 1.5ms preprocess, 118.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1268.jpg: 640x384 2 persons, 136.1ms
# Speed: 1.4ms preprocess, 136.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0312.jpg: 640x384 1 person, 244.2ms
# Speed: 21.5ms preprocess, 244.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0161.jpg: 640x384 1 person, 273.9ms
# Speed: 11.9ms preprocess, 273.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0607.jpg: 640x384 2 persons, 1 clock, 241.6ms
# Speed: 13.5ms preprocess, 241.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1284.jpg: 640x384 1 person, 142.7ms
# Speed: 1.5ms preprocess, 142.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1207.jpg: 640x384 (no detections), 132.6ms
# Speed: 13.8ms preprocess, 132.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0856.jpg: 640x384 3 persons, 124.5ms
# Speed: 3.7ms preprocess, 124.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0354.jpg: 640x384 1 person, 165.2ms
# Speed: 6.1ms preprocess, 165.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0224.jpg: 640x384 2 persons, 1 umbrella, 99.3ms
# Speed: 2.2ms preprocess, 99.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0931.jpg: 640x384 3 persons, 103.7ms
# Speed: 2.8ms preprocess, 103.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0911.jpg: 640x384 3 persons, 173.5ms
# Speed: 1.7ms preprocess, 173.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0204.jpg: 640x384 2 persons, 156.4ms
# Speed: 1.9ms preprocess, 156.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0729.jpg: 640x384 1 car, 1 truck, 1 clock, 276.4ms
# Speed: 2.1ms preprocess, 276.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0391.jpg: 640x384 2 mouses, 215.7ms
# Speed: 2.6ms preprocess, 215.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0456.jpg: 640x384 1 person, 1 vase, 166.2ms
# Speed: 1.8ms preprocess, 166.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0362.jpg: 640x384 1 mouse, 132.2ms
# Speed: 2.0ms preprocess, 132.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0846.jpg: 640x384 3 persons, 116.6ms
# Speed: 2.2ms preprocess, 116.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1283.jpg: 640x384 1 person, 124.5ms
# Speed: 2.3ms preprocess, 124.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0747.jpg: 640x384 1 refrigerator, 122.8ms
# Speed: 1.8ms preprocess, 122.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1272.jpg: 640x384 1 person, 1 vase, 99.8ms
# Speed: 1.9ms preprocess, 99.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1079.jpg: 640x384 1 person, 81.0ms
# Speed: 1.4ms preprocess, 81.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1030.jpg: 640x384 1 person, 76.6ms
# Speed: 1.4ms preprocess, 76.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0103.jpg: 640x384 1 person, 137.7ms
# Speed: 1.5ms preprocess, 137.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0102.jpg: 640x384 1 person, 99.8ms
# Speed: 3.8ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1109.jpg: 640x384 1 person, 1 chair, 144.2ms
# Speed: 3.1ms preprocess, 144.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0009.jpg: 640x384 2 persons, 169.1ms
# Speed: 2.4ms preprocess, 169.1ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0385.jpg: 640x384 1 person, 1 mouse, 152.3ms
# Speed: 1.4ms preprocess, 152.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1076.jpg: 640x384 1 person, 160.0ms
# Speed: 7.1ms preprocess, 160.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0672.jpg: 640x384 (no detections), 121.9ms
# Speed: 1.4ms preprocess, 121.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0326.jpg: 640x384 1 person, 99.9ms
# Speed: 5.0ms preprocess, 99.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_
6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0183.jpg: 640x384 2 persons, 110.8ms
# Speed: 2.0ms preprocess, 110.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1229.jpg: 640x384 (no detections), 115.5ms
# Speed: 4.0ms preprocess, 115.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0798.jpg: 640x384 3 persons, 1 refrigerator, 137.0ms
# Speed: 1.4ms preprocess, 137.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1102.jpg: 640x384 4 persons, 1 umbrella, 106.3ms
# Speed: 1.6ms preprocess, 106.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1111.jpg: 640x384 1 person, 1 chair, 101.9ms
# Speed: 2.3ms preprocess, 101.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0870.jpg: 640x384 3 persons, 1 clock, 116.9ms
# Speed: 2.0ms preprocess, 116.9ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1013.jpg: 640x384 3 persons, 1 umbrella, 1 tv, 135.4ms
# Speed: 1.5ms preprocess, 135.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1208.jpg: 640x384 1 mouse, 123.0ms
# Speed: 14.9ms preprocess, 123.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0678.jpg: 640x384 (no detections), 120.2ms
# Speed: 1.6ms preprocess, 120.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0881.jpg: 640x384 3 persons, 142.7ms
# Speed: 1.5ms preprocess, 142.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0264.jpg: 640x384 2 persons, 1 umbrella, 128.1ms
# Speed: 1.9ms preprocess, 128.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0472.jpg: 640x384 1 person, 1 umbrella, 149.3ms
# Speed: 5.3ms preprocess, 149.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0923.jpg: 640x384 3 persons, 135.4ms
# Speed: 8.3ms preprocess, 135.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0275.jpg: 640x384 2 persons, 1 umbrella, 97.5ms
# Speed: 3.8ms preprocess, 97.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1241.jpg: 640x384 (no detections), 171.3ms
# Speed: 5.7ms preprocess, 171.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0645.jpg: 640x384 (no detections), 84.1ms
# Speed: 1.3ms preprocess, 84.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0147.jpg: 640x384 1 person, 118.8ms
# Speed: 2.1ms preprocess, 118.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1198.jpg: 640x384 1 person, 1 bottle, 129.8ms
# Speed: 4.9ms preprocess, 129.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0240.jpg: 640x384 2 persons, 1 umbrella, 116.9ms
# Speed: 4.0ms preprocess, 116.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1240.jpg: 640x384 (no detections), 108.7ms
# Speed: 1.7ms preprocess, 108.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0650.jpg: 640x384 (no detections), 125.6ms
# Speed: 1.9ms preprocess, 125.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0374.jpg: 640x384 1 mouse, 137.7ms
# Speed: 1.8ms preprocess, 137.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0874.jpg: 640x384 3 persons, 1 clock, 110.6ms
# Speed: 2.1ms preprocess, 110.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0189.jpg: 640x384 2 persons, 98.9ms
# Speed: 6.0ms preprocess, 98.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0603.jpg: 640x384 2 persons, 1 dog, 1 clock, 198.7ms
# Speed: 1.3ms preprocess, 198.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0234.jpg: 640x384 2 persons, 1 umbrella, 386.0ms
# Speed: 3.8ms preprocess, 386.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0653.jpg: 640x384 1 car, 179.5ms
# Speed: 8.1ms preprocess, 179.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0589.jpg: 640x384 3 persons, 127.6ms
# Speed: 1.3ms preprocess, 127.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1117.jpg: 640x384 1 person, 1 chair, 120.7ms
# Speed: 1.5ms preprocess, 120.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1183.jpg: 640x384 2 persons, 1 bottle, 150.9ms
# Speed: 2.5ms preprocess, 150.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0365.jpg: 640x384 1 mouse, 131.8ms
# Speed: 1.3ms preprocess, 131.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0153.jpg: 640x384 1 person, 426.8ms
# Speed: 1.5ms preprocess, 426.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0026.jpg: 640x384 2 persons, 143.3ms
# Speed: 1.6ms preprocess, 143.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1172.jpg: 640x384 2 persons, 1 refrigerator, 125.5ms
# Speed: 11.5ms preprocess, 125.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0582.jpg: 640x384 3 persons, 1 refrigerator, 110.8ms
# Speed: 2.5ms preprocess, 110.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0922.jpg: 640x384 3 persons, 97.3ms
# Speed: 1.9ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0406.jpg: 640x384 (no detections), 101.5ms
# Speed: 2.1ms preprocess, 101.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1218.jpg: 640x384 (no detections), 138.1ms
# Speed: 1.6ms preprocess, 138.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0376.jpg: 640x384 1 person, 1 mouse, 117.4ms
# Speed: 2.9ms preprocess, 117.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0387.jpg: 640x384 1 person, 1 mouse, 165.0ms
# Speed: 1.6ms preprocess, 165.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0993.jpg: 640x384 3 persons, 1 tv, 109.8ms
# Speed: 2.9ms preprocess, 109.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0352.jpg: 640x384 1 person, 135.0ms
# Speed: 6.0ms preprocess, 135.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0531.jpg: 640x384 (no detections), 107.7ms
# Speed: 2.4ms preprocess, 107.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0884.jpg: 640x384 3 persons, 123.6ms
# Speed: 1.5ms preprocess, 123.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0452.jpg: 640x384 1 person, 1 vase, 132.5ms
# Speed: 1.7ms preprocess, 132.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0142.jpg: 640x384 1 person, 145.2ms
# Speed: 1.8ms preprocess, 145.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0373.jpg: 640x384 1 mouse, 126.6ms
# Speed: 2.0ms preprocess, 126.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0673.jpg: 640x384 (no detections), 134.0ms
# Speed: 3.1ms preprocess, 134.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1182.jpg: 640x384 2 persons, 1 bottle, 119.0ms
# Speed: 1.7ms preprocess, 119.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0000.jpg: 640x384 1 person, 157.1ms
# Speed: 7.7ms preprocess, 157.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0372.jpg: 640x384 1 person, 1 mouse, 165.6ms
# Speed: 3.2ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1254.jpg: 640x384 2 persons, 2 umbrellas, 307.9ms
# Speed: 1.9ms preprocess, 307.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0351.jpg: 640x384 (no detections), 181.8ms
# Speed: 4.1ms preprocess, 181.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0396.jpg: 640x384 (no detections), 153.8ms
# Speed: 1.6ms preprocess, 153.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1167.jpg: 640x384 3 persons, 1 bottle, 1 cup, 139.0ms
# Speed: 2.8ms preprocess, 139.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1055.jpg: 640x384 1 person, 2 cell phones, 106.1ms
# Speed: 1.6ms preprocess, 106.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0389.jpg: 640x384 1 person, 1 mouse, 100.7ms
# Speed: 1.6ms preprocess, 100.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0368.jpg: 640x384 1 mouse, 167.3ms
# Speed: 2.4ms preprocess, 167.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1289.jpg: 640x384 1 person, 139.0ms
# Speed: 1.3ms preprocess, 139.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1007.jpg: 640x384 3 persons, 1 refrigerator, 120.3ms
# Speed: 4.5ms preprocess, 120.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0932.jpg: 640x384 3 persons, 134.8ms
# Speed: 3.6ms preprocess, 134.8ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1184.jpg: 640x384 2 persons, 1 bottle, 228.4ms
# Speed: 10.9ms preprocess, 228.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0450.jpg: 640x384 1 person, 1 vase, 101.7ms
# Speed: 2.6ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0886.jpg: 640x384 3 persons, 96.8ms
# Speed: 1.4ms preprocess, 96.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1064.jpg: 640x384 1 person, 1 umbrella, 1 cell phone, 98.9ms
# Speed: 1.6ms preprocess, 98.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0059.jpg: 640x384 1 person, 102.4ms
# Speed: 1.4ms preprocess, 102.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0141.jpg: 640x384 1 person, 119.3ms
# Speed: 1.4ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0269.jpg: 640x384 2 persons, 127.7ms
# Speed: 2.4ms preprocess, 127.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0330.jpg: 640x384 1 person, 100.9ms
# Speed: 2.2ms preprocess, 100.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1293.jpg: 640x384 1 person, 1 umbrella, 99.3ms
# Speed: 1.8ms preprocess, 99.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0550.jpg: 640x384 1 person, 1 vase, 101.7ms
# Speed: 1.5ms preprocess, 101.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0857.jpg: 640x384 3 persons, 121.9ms
# Speed: 1.4ms preprocess, 121.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0356.jpg: 640x384 1 person, 115.2ms
# Speed: 4.0ms preprocess, 115.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0569.jpg: 640x384 3 persons, 122.1ms
# Speed: 1.6ms preprocess, 122.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0480.jpg: 640x384 1 person, 1 umbrella, 1 vase, 96.4ms
# Speed: 4.4ms preprocess, 96.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1035.jpg: 640x384 1 person, 100.2ms
# Speed: 4.2ms preprocess, 100.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0382.jpg: 640x384 1 person, 1 mouse, 107.0ms
# Speed: 1.6ms preprocess, 107.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1052.jpg: 640x384 1 person, 129.1ms
# Speed: 2.7ms preprocess, 129.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1204.jpg: 640x384 (no detections), 126.8ms
# Speed: 2.0ms preprocess, 126.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0022.jpg: 640x384 2 persons, 118.2ms
# Speed: 2.7ms preprocess, 118.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0869.jpg: 640x384 3 persons, 1 clock, 97.3ms
# Speed: 2.8ms preprocess, 97.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1116.jpg: 640x384 1 person, 1 chair, 99.4ms
# Speed: 1.7ms preprocess, 99.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1048.jpg: 640x384 1 person, 1 cell phone, 99.3ms
# Speed: 1.5ms preprocess, 99.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0207.jpg: 640x384 2 persons, 123.9ms
# Speed: 1.6ms preprocess, 123.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1171.jpg: 640x384 1 person, 134.9ms
# Speed: 1.7ms preprocess, 134.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1135.jpg: 640x384 2 persons, 1 chair, 107.7ms
# Speed: 3.0ms preprocess, 107.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0501.jpg: 640x384 1 person, 1 vase, 102.4ms
# Speed: 1.9ms preprocess, 102.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0892.jpg: 640x384 3 persons, 122.9ms
# Speed: 1.5ms preprocess, 122.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0370.jpg: 640x384 (no detections), 149.4ms
# Speed: 2.3ms preprocess, 149.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1003.jpg: 640x384 3 persons, 112.7ms
# Speed: 1.8ms preprocess, 112.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0818.jpg: 640x384 3 persons, 98.0ms
# Speed: 1.4ms preprocess, 98.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0987.jpg: 640x384 3 persons, 124.6ms
# Speed: 3.6ms preprocess, 124.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0032.jpg: 640x384 2 persons, 156.8ms
# Speed: 1.8ms preprocess, 156.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0485.jpg: 640x384 1 person, 1 umbrella, 103.2ms
# Speed: 1.6ms preprocess, 103.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0286.jpg: 640x384 2 persons, 1 umbrella, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0873.jpg: 640x384 3 persons, 1 clock, 128.6ms
# Speed: 2.8ms preprocess, 128.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0074.jpg: 640x384 1 person, 135.1ms
# Speed: 1.8ms preprocess, 135.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0325.jpg: 640x384 1 person, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0097.jpg: 640x384 1 person, 106.4ms
# Speed: 3.5ms preprocess, 106.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0766.jpg: 640x384 (no detections), 136.5ms
# Speed: 2.2ms preprocess, 136.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0160.jpg: 640x384 1 person, 121.9ms
# Speed: 1.5ms preprocess, 121.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0614.jpg: 640x384 2 persons, 1 dog, 1 clock, 114.4ms
# Speed: 2.5ms preprocess, 114.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1238.jpg: 640x384 (no detections), 100.8ms
# Speed: 2.5ms preprocess, 100.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# ...
# Speed: 1.2ms preprocess, 125.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0916.jpg: 640x384 3 persons, 103.8ms
# Speed: 2.0ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0431.jpg: 640x384 2 persons, 2 umbrellas, 132.1ms
# Speed: 1.5ms preprocess, 132.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1212.jpg: 640x384 1 mouse, 121.2ms
# Speed: 1.9ms preprocess, 121.2ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0711.jpg: 640x384 1 car, 188.9ms
# Speed: 12.8ms preprocess, 188.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0558.jpg: 640x384 1 vase, 176.5ms
# Speed: 2.7ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0470.jpg: 640x384 1 person, 1 umbrella, 215.8ms
# Speed: 2.7ms preprocess, 215.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0125.jpg: 640x384 1 person, 150.5ms
# Speed: 3.6ms preprocess, 150.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0889.jpg: 640x384 3 persons, 179.5ms
# Speed: 1.5ms preprocess, 179.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0596.jpg: 640x384 2 persons, 1 clock, 172.3ms
# Speed: 1.6ms preprocess, 172.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0699.jpg: 640x384 1 car, 222.3ms
# Speed: 5.1ms preprocess, 222.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0473.jpg: 640x384 1 person, 1 umbrella, 115.2ms
# Speed: 1.4ms preprocess, 115.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1022.jpg: 640x384 1 person, 1 umbrella, 197.0ms
# Speed: 8.0ms preprocess, 197.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0912.jpg: 640x384 4 persons, 122.3ms
# Speed: 5.5ms preprocess, 122.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0933.jpg: 640x384 3 persons, 156.7ms
# Speed: 1.8ms preprocess, 156.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0757.jpg: 640x384 1 refrigerator, 115.7ms
# Speed: 2.2ms preprocess, 115.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0591.jpg: 640x384 3 persons, 1 knife, 175.6ms
# Speed: 3.8ms preprocess, 175.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0359.jpg: 640x384 1 person, 161.2ms
# Speed: 6.4ms preprocess, 161.2ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0115.jpg: 640x384 1 person, 135.4ms
# Speed: 2.2ms preprocess, 135.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1279.jpg: 640x384 1 person, 128.1ms
# Speed: 4.9ms preprocess, 128.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0920.jpg: 640x384 3 persons, 161.3ms
# Speed: 1.4ms preprocess, 161.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0786.jpg: 640x384 3 persons, 1 tv, 1 clock, 189.2ms
# Speed: 8.0ms preprocess, 189.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0843.jpg: 640x384 3 persons, 149.2ms
# Speed: 4.0ms preprocess, 149.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0236.jpg: 640x384 2 persons, 1 umbrella, 167.6ms
# Speed: 1.8ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0821.jpg: 640x384 3 persons, 136.1ms
# Speed: 3.9ms preprocess, 136.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0132.jpg: 640x384 1 person, 118.2ms
# Speed: 2.7ms preprocess, 118.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0090.jpg: 640x384 1 person, 448.6ms
# Speed: 1.6ms preprocess, 448.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0357.jpg: 640x384 1 person, 166.4ms
# Speed: 11.6ms preprocess, 166.4ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0789.jpg: 640x384 3 persons, 1 tv, 139.2ms
# Speed: 2.2ms preprocess, 139.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0900.jpg: 640x384 3 persons, 205.7ms
# Speed: 3.6ms preprocess, 205.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0799.jpg: 640x384 3 persons, 1 refrigerator, 143.0ms
# Speed: 2.4ms preprocess, 143.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1059.jpg: 640x384 1 person, 1 umbrella, 1 cell phone, 231.0ms
# Speed: 2.8ms preprocess, 231.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0767.jpg: 640x384 (no detections), 151.7ms
# Speed: 7.0ms preprocess, 151.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1110.jpg: 640x384 1 person, 1 chair, 226.2ms
# Speed: 9.6ms preprocess, 226.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0960.jpg: 640x384 3 persons, 215.5ms
# Speed: 1.9ms preprocess, 215.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1105.jpg: 640x384 1 person, 1 umbrella, 128.1ms
# Speed: 2.7ms preprocess, 128.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0518.jpg: 640x384 (no detections), 166.4ms
# Speed: 4.0ms preprocess, 166.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0771.jpg: 640x384 (no detections), 126.4ms
# Speed: 12.6ms preprocess, 126.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0566.jpg: 640x384 3 persons, 253.9ms
# Speed: 2.5ms preprocess, 253.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0065.jpg: 640x384 1 person, 208.9ms
# Speed: 1.6ms preprocess, 208.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0056.jpg: 640x384 1 person, 207.2ms
# Speed: 11.2ms preprocess, 207.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0661.jpg: 640x384 (no detections), 188.8ms
# Speed: 12.8ms preprocess, 188.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0086.jpg: 640x384 1 person, 152.2ms
# Speed: 1.3ms preprocess, 152.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0703.jpg: 640x384 1 car, 172.6ms
# Speed: 3.4ms preprocess, 172.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0745.jpg: 640x384 1 person, 1 car, 1 tv, 140.0ms
# Speed: 2.7ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1197.jpg: 640x384 1 cup, 2 mouses, 137.4ms
# Speed: 12.5ms preprocess, 137.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1185.jpg: 640x384 2 persons, 1 bottle, 102.0ms
# Speed: 1.8ms preprocess, 102.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0992.jpg: 640x384 3 persons, 1 refrigerator, 152.7ms
# Speed: 9.5ms preprocess, 152.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0197.jpg: 640x384 2 persons, 182.8ms
# Speed: 7.6ms preprocess, 182.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0053.jpg: 640x384 2 persons, 162.0ms
# Speed: 1.9ms preprocess, 162.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0530.jpg: 640x384 (no detections), 133.4ms
# Speed: 1.8ms preprocess, 133.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0527.jpg: 640x384 (no detections), 198.9ms
# Speed: 3.3ms preprocess, 198.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0180.jpg: 640x384 2 persons, 149.0ms
# Speed: 5.8ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0896.jpg: 640x384 3 persons, 126.1ms
# Speed: 3.0ms preprocess, 126.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0553.jpg: 640x384 1 vase, 158.1ms
# Speed: 3.5ms preprocess, 158.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0333.jpg: 640x384 1 person, 131.0ms
# Speed: 2.0ms preprocess, 131.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0640.jpg: 640x384 1 person, 136.1ms
# Speed: 2.3ms preprocess, 136.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1015.jpg: 640x384 3 persons, 1 tv, 172.6ms
# Speed: 4.6ms preprocess, 172.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0568.jpg: 640x384 3 persons, 126.9ms
# Speed: 5.4ms preprocess, 126.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0988.jpg: 640x384 4 persons, 1 refrigerator, 108.3ms
# Speed: 1.9ms preprocess, 108.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1136.jpg: 640x384 1 person, 1 backpack, 1 chair, 100.1ms
# Speed: 2.1ms preprocess, 100.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1247.jpg: 640x384 2 persons, 2 umbrellas, 147.0ms
# Speed: 1.6ms preprocess, 147.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0177.jpg: 640x384 2 persons, 147.8ms
# Speed: 2.2ms preprocess, 147.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0926.jpg: 640x384 3 persons, 118.5ms
# Speed: 2.4ms preprocess, 118.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1005.jpg: 640x384 3 persons, 1 refrigerator, 151.8ms
# Speed: 2.0ms preprocess, 151.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0795.jpg: 640x384 4 persons, 1 clock, 179.6ms
# Speed: 2.1ms preprocess, 179.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0980.jpg: 640x384 3 persons, 120.5ms
# Speed: 3.0ms preprocess, 120.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1243.jpg: 640x384 2 persons, 2 umbrellas, 162.9ms
# Speed: 2.3ms preprocess, 162.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_0831.jpg: 640x384 3 persons, 145.4ms
# Speed: 1.4ms preprocess, 145.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/bok/ai_1/vision-ai-inference-practice/4. video-ai-inference/frames2/frame_1264.jpg: 640x384 1 person, 118.1ms
# Speed: 2.6ms preprocess, 118.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# ### 5. 프레임을 동영상으로 변환 - moviepy 라이브러리

# %%
# 이미지 파일들이 저장된 디렉토리 경로
image_folder = "results"  # 이미지 파일들이 있는 폴더 경로
fps = int(fps)  # 초당 프레임 수 설정

# 이미지 파일 리스트 가져오기 (예: jpg, png 형식)
image_files = [
    os.path.join(image_folder, img)
    for img in sorted(os.listdir(image_folder))
    if img.endswith((".jpg", ".png"))
]

# 이미지 시퀀스를 이용해 클립 생성
clip = ImageSequenceClip(image_files, fps=fps)

# 동영상 파일로 저장
output_path = "output_video.mp4"
clip.write_videofile(output_path, codec="libx264")

print(f"동영상이 생성되었습니다: {output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 이미지 파일들이 저장된 디렉토리 경로
#       2 image_folder = "results"  # 이미지 파일들이 있는 폴더 경로
# ----> 3 fps = int(fps)  # 초당 프레임 수 설정
#       5 # 이미지 파일 리스트 가져오기 (예: jpg, png 형식)
#       6 image_files = [
#       7     os.path.join(image_folder, img)
#       8     for img in sorted(os.listdir(image_folder))
#       9     if img.endswith((".jpg", ".png"))
#      10 ]
#
# NameError: name 'fps' is not defined

# %%
import cv2
import os

# 이미지들이 저장된 폴더 경로와 저장할 비디오 파일 이름 설정
image_folder = 'results2'  # 이미지들이 저장된 폴더 경로
video_name = 'output_video3.mp4'  # 저장할 비디오 파일 이름

# 이미지 파일 이름을 읽고 정렬 (순서대로 동영상을 만들기 위해)
images = [img for img in os.listdir(image_folder) if img.endswith(".png") or img.endswith(".jpg")]
images.sort()

# 첫 번째 이미지에서 프레임의 너비와 높이 가져오기
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

# 비디오 코덱과 파일명 설정, FPS 설정
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # mp4 코덱 설정
video = cv2.VideoWriter(video_name, fourcc, 30, (width, height))  # FPS를 30으로 설정

# 이미지를 순차적으로 불러와서 비디오에 추가
for image in images:
    frame = cv2.imread(os.path.join(image_folder, image))
    video.write(frame)

# 비디오 파일 저장 종료
video.release()
cv2.destroyAllWindows()
